# %%
# %load_ext autoreload
# %autoreload 2

# %%
# getting the utils file here
import os, sys
import xbos_services_getter as xsg
import datetime
import calendar
import pytz
import numpy as np
import pandas as pd
import itertools
import time
from pathlib import Path
import pickle
import yaml

# %%
pd.set_option('display.max_columns', None)

# %%
import process_indoor_data as pid
import create_models as ctm

# %%
import matplotlib.pyplot as plt

# %%
building_zone_names_stub = xsg.get_building_zone_names_stub()
all_buildings_zones = xsg.get_all_buildings_zones(building_zone_names_stub)

# %%
# Get predictions 
indoor_temperature_prediction_stub = xsg.get_indoor_temperature_prediction_stub()
t_in = 79.69
t_out = 70
t_prev = 80
action = 1
building = "jesse-turner-center"
zone = "hvac_zone_kitchen"
current_time = datetime.datetime(year=2018, month=7, day=1).replace(tzinfo=pytz.utc)
other_zone_temperatures = {}
for iter_zone in all_buildings_zones[building]:
    if iter_zone != zone:
        other_zone_temperatures[iter_zone] = 70


xsg.get_indoor_temperature_prediction(indoor_temperature_prediction_stub, building, zone, current_time, action, t_in, t_out, t_prev,
                                      other_zone_temperatures)
# Out:
# (79.3878688967897, datetime.datetime(2018, 7, 1, 0, 5, tzinfo=<UTC>), 'F')

# %%
prediction_window = "5m"
seconds_prediction_window = xsg.get_window_in_sec(prediction_window)
start = datetime.datetime(year=2018, month=7, day=1).replace(tzinfo=pytz.utc)
end = start + datetime.timedelta(days=10)

# %%
data_stub = xsg.get_indoor_historic_stub()
bldg = "jesse-turner-center"
zone = "hvac_zone_kitchen"
a = xsg.get_actions_historic(data_stub, bldg, zone, start, end, "1m")
# b = xsg.get_indoor_temperature_historic(data_stub, bldg, zone, start, end, "1m")
# Out:
# ---------------------------------------------------------------------------
# _Rendezvous                               Traceback (most recent call last)
# <ipython-input-40-05679552136f> in <module>
#       2 bldg = "jesse-turner-center"
#       3 zone = "hvac_zone_kitchen"
# ----> 4 a = xsg.get_actions_historic(data_stub, bldg, zone, start, end, "1m")
#       5 # b = xsg.get_indoor_temperature_historic(data_stub, bldg, zone, start, end, "1m")
#
# ~/BETS/xbos_services_getter/xbos_services_getter/xbos_services_getter.py in get_actions_historic(indoor_historic_stub, building, zone, start, end, window)
#     415     historic_action_response = indoor_historic_stub.GetRawActions(
#     416         indoor_temperature_action_pb2.Request(building=building, zone=zone, start=start_unix, end=end_unix,
# --> 417                                               window=window))
#     418
#     419     # process data
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials)
#     531     def __call__(self, request, timeout=None, metadata=None, credentials=None):
#     532         state, call, = self._blocking(request, timeout, metadata, credentials)
# --> 533         return _end_unary_response_blocking(state, call, False, None)
#     534
#     535     def with_call(self, request, timeout=None, metadata=None, credentials=None):
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     465             return state.response
#     466     else:
# --> 467         raise _Rendezvous(state, None, None, deadline)
#     468
#     469
#
# _Rendezvous: <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "Exception calling application: <_Rendezvous of RPC that terminated with (StatusCode.CANCELLED, Received http2 header with status: 502)>"
# 	debug_error_string = "{"created":"@1555526825.455204000","description":"Error received from peer","file":"src/core/lib/surface/call.cc","file_line":1017,"grpc_message":"Exception calling application: <_Rendezvous of RPC that terminated with (StatusCode.CANCELLED, Received http2 header with status: 502)>","grpc_status":2}"
# >

# %%
a
# Out:
# 2018-07-01 00:00:00+00:00    2.0
# 2018-07-01 00:01:00+00:00    2.0
# 2018-07-01 00:02:00+00:00    2.0
# 2018-07-01 00:03:00+00:00    2.0
# 2018-07-01 00:04:00+00:00    2.0
# 2018-07-01 00:05:00+00:00    2.0
# 2018-07-01 00:06:00+00:00    2.0
# 2018-07-01 00:07:00+00:00    2.0
# 2018-07-01 00:08:00+00:00    2.0
# 2018-07-01 00:09:00+00:00    2.0
# 2018-07-01 00:10:00+00:00    2.0
# 2018-07-01 00:11:00+00:00    2.0
# 2018-07-01 00:12:00+00:00    2.0
# 2018-07-01 00:13:00+00:00    2.0
# 2018-07-01 00:14:00+00:00    2.0
# 2018-07-01 00:15:00+00:00    2.0
# 2018-07-01 00:16:00+00:00    2.0
# 2018-07-01 00:17:00+00:00    2.0
# 2018-07-01 00:18:00+00:00    2.0
# 2018-07-01 00:19:00+00:00    2.0
# 2018-07-01 00:20:00+00:00    2.0
# 2018-07-01 00:21:00+00:00    2.0
# 2018-07-01 00:22:00+00:00    2.0
# 2018-07-01 00:23:00+00:00    2.0
# 2018-07-01 00:24:00+00:00    2.0
# 2018-07-01 00:25:00+00:00    2.0
# 2018-07-01 00:26:00+00:00    2.0
# 2018-07-01 00:27:00+00:00    2.0
# 2018-07-01 00:28:00+00:00    2.0
# 2018-07-01 00:29:00+00:00    2.0
#                             ...
# 2018-07-10 23:30:00+00:00    5.0
# 2018-07-10 23:31:00+00:00    5.0
# 2018-07-10 23:32:00+00:00    5.0
# 2018-07-10 23:33:00+00:00    5.0
# 2018-07-10 23:34:00+00:00    5.0
# 2018-07-10 23:35:00+00:00    5.0
# 2018-07-10 23:36:00+00:00    5.0
# 2018-07-10 23:37:00+00:00    5.0
# 2018-07-10 23:38:00+00:00    5.0
# 2018-07-10 23:39:00+00:00    5.0
# 2018-07-10 23:40:00+00:00    5.0
# 2018-07-10 23:41:00+00:00    5.0
# 2018-07-10 23:42:00+00:00    5.0
# 2018-07-10 23:43:00+00:00    5.0
# 2018-07-10 23:44:00+00:00    5.0
# 2018-07-10 23:45:00+00:00    5.0
# 2018-07-10 23:46:00+00:00    5.0
# 2018-07-10 23:47:00+00:00    5.0
# 2018-07-10 23:48:00+00:00    5.0
# 2018-07-10 23:49:00+00:00    5.0
# 2018-07-10 23:50:00+00:00    5.0
# 2018-07-10 23:51:00+00:00    5.0
# 2018-07-10 23:52:00+00:00    5.0
# 2018-07-10 23:53:00+00:00    5.0
# 2018-07-10 23:54:00+00:00    5.0
# 2018-07-10 23:55:00+00:00    5.0
# 2018-07-10 23:56:00+00:00    5.0
# 2018-07-10 23:57:00+00:00    5.0
# 2018-07-10 23:58:00+00:00    5.0
# 2018-07-10 23:59:00+00:00    5.0
# Freq: 60S, Length: 14400, dtype: float64

# %%
data_stub = xsg.get_indoor_historic_stub()
for bldg in all_buildings_zones.keys():
    print("Getting bldg", bldg)
    for zone in all_buildings_zones[bldg]:
        print("getting zone", zone)
        s_time = time.time()
        a = xsg.get_actions_historic(data_stub, bldg, zone, start, end, "1m")
        b = xsg.get_indoor_temperature_historic(data_stub, bldg, zone, start, end, "1m")
        print("Temp shape", b.shape)
        print("Action shape", a.shape)
        print("Took:", time.time() - s_time)
    print("")
# Out:
# Getting bldg jesse-turner-center
# getting zone hvac_zone_resource_center
# Temp shape (14400,)
# Action shape (14400,)
# Took: 6.357602119445801
# getting zone hvac_zone_class_132
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.495712995529175
# getting zone hvac_zone_meeting_room_122
# Temp shape (14400,)
# Action shape (14400,)
# Took: 6.001239061355591
# getting zone hvac_zone_multi_purpose_147
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.884548902511597
# getting zone hvac_zone_fitness_room_138
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.617478847503662
# getting zone hvac_zone_assembly_112
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.624169111251831
# getting zone hvac_zone_basketball_court_2
# Temp shape (14400,)
# Action shape (14400,)
# Took: 0.43511390686035156
# getting zone hvac_zone_basketball_court_6
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.946195125579834
# getting zone hvac_zone_basketball_court_5
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.756210803985596
# getting zone hvac_zone_lobby
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.614386796951294
# getting zone hvac_zone_basketball_court_3
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.47610330581665
# getting zone hvac_zone_control_desk
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.924778938293457
# getting zone hvac_zone_foyer_gallery
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.587488174438477
# getting zone hvac_zone_assembly_113
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.530786037445068
# getting zone hvac_zone_class_131
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.698585033416748
# getting zone hvac_zone_front_entrance
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.5738959312438965
# getting zone hvac_zone_office_room_148
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.555887222290039
# getting zone hvac_zone_basketball_court_4
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.731734991073608
# getting zone hvac_zone_dance_room_109
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.520090103149414
# getting zone hvac_zone_back_stage
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.4462010860443115
# getting zone hvac_zone_basketball_court_1
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.424170970916748
# getting zone hvac_zone_kitchen
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.511906147003174
# getting zone hvac_zone_assembly_111
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.425580024719238
# getting zone hvac_zone_electrical_room123
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.438070058822632
#
# Getting bldg ciee
# getting zone hvac_zone_centralzone
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.547815799713135
# getting zone hvac_zone_eastzone
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.629925727844238
# getting zone hvac_zone_northzone
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.352148056030273
# getting zone hvac_zone_southzone
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.189166069030762
#
# Getting bldg csu-dominguez-hills
# getting zone hvac_zone_sac_2101
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.518748998641968
# getting zone hvac_zone_sac_2114
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.473512887954712
# getting zone hvac_zone_sac_2150
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.687703609466553
# getting zone hvac_zone_sac_2126
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.568458080291748
# getting zone hvac_zone_please_delete_me
# Temp shape (14400,)
# Action shape (14400,)
# Took: 0.1665799617767334
# getting zone hvac_zone_sac_2113a
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.31976318359375
# getting zone hvac_zone_sac_2104
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.4796507358551025
# getting zone hvac_zone_sac_2_corridor
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.783685207366943
# getting zone hvac_zone_sac_2106
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.820155143737793
# getting zone hvac_zone_sac_2129
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.4205100536346436
# getting zone hvac_zone_sac_2107
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.648708820343018
# getting zone hvac_zone_sac_2113
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.830419301986694
# getting zone hvac_zone_sac_2149
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.452594995498657
# getting zone hvac_zone_sac_2102
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.709986209869385
# getting zone hvac_zone_sac_2103
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.708799839019775
# getting zone hvac_zone_sac_2144
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.5367138385772705
# getting zone hvac_zone_sac_2105
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.623502969741821
# getting zone hvac_zone_sac_2134
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.555239915847778
#
# Getting bldg hayward-station-8
# getting zone hvac_zone_f_3
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.419543027877808
# getting zone hvac_zone_f_1
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.345875024795532
# getting zone hvac_zone_f_2
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.401837110519409
#
# Getting bldg avenal-movie-theatre
# getting zone hvac_zone_lobby
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.3295581340789795
# getting zone hvac_zone_main_hallway
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.3025171756744385
# getting zone hvac_zone_room_a
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.586979150772095
# getting zone hvac_zone_theater_2
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.794042110443115
# getting zone hvac_zone_back_hallway
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.246025800704956
# getting zone hvac_zone_room_d
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.5782670974731445
# getting zone hvac_zone_pegasus_hall
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.386013984680176
# getting zone hvac_zone_theater_1
# Temp shape (14400,)
# Action shape (14400,)
# Took: 3.010394334793091
#
# Getting bldg word-of-faith-cc
# getting zone hvac_zone_hospitality
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.613710641860962
# getting zone hvac_zone_fellowship_hall
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.625060081481934
# getting zone hvac_zone_lobby
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.588809013366699
# getting zone hvac_zone_sanctuary_lb_2
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.60745096206665
# getting zone hvac_zone_sanctuary_rf_2
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.586205005645752
# getting zone hvac_zone_school_age_rm
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.697548866271973
# getting zone hvac_zone_pre_k_classroom
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.443479061126709
#
# Getting bldg hayward-station-1
# getting zone hvac_zone_ac_2
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.314239025115967
# getting zone hvac_zone_ac_3
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.5095438957214355
# getting zone hvac_zone_ac_4
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.5416481494903564
# getting zone hvac_zone_ac_5
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.40362811088562
# getting zone hvac_zone_ac_6
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.626104116439819
# getting zone hvac_zone_ac_7
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.476042985916138
# getting zone hvac_zone_ac_1
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.411823034286499
#
# Getting bldg avenal-veterans-hall
# getting zone hvac_zone_ac_3
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.492234945297241
# getting zone hvac_zone_ac_1
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.630237102508545
# getting zone hvac_zone_ac_4
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.4653167724609375
# getting zone hvac_zone_ac_6
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.521950960159302
# getting zone hvac_zone_ac_5
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.324068307876587
# getting zone hvac_zone_ac_2
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.331171035766602
#
# Getting bldg avenal-animal-shelter
# getting zone hvac_zone_shelter_corridor
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.260486125946045
#
# Getting bldg south-berkeley-senior-center
# getting zone hvac_zone_ac_2
# Temp shape (14400,)
# Action shape (14400,)
# Took: 3.7092957496643066
# getting zone hvac_zone_ac_3
# Temp shape (14400,)
# Action shape (14400,)
# Took: 3.4713330268859863
# getting zone hvac_zone_front_office
# Temp shape (14400,)
# Action shape (14400,)
# Took: 3.940023183822632
#
# Getting bldg local-butcher-shop
# getting zone hvac_zone_retail_space
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.496605157852173
#
# Getting bldg avenal-recreation-center
# getting zone hvac_zone_large_room
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.333225965499878
# getting zone hvac_zone_tech_center
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.339588165283203
#
# Getting bldg orinda-community-center
# getting zone hvac_zone_ac_7
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.409584283828735
# getting zone hvac_zone_rm7
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.2420289516448975
# getting zone hvac_zone_kinder_gym
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.225455045700073
# getting zone hvac_zone_ac_6
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.250916242599487
# getting zone hvac_zone_ac_3
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.241614103317261
# getting zone hvac_zone_rm1
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.18642783164978
# getting zone hvac_zone_ac_4
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.304533004760742
# getting zone hvac_zone_ac_5
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.430351972579956
# getting zone hvac_zone_rm6
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.4747350215911865
# getting zone hvac_zone_ac_1
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.312132120132446
# getting zone hvac_zone_front_office
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.153350830078125
# getting zone hvac_zone_ac_2
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.350670099258423
# getting zone hvac_zone_rm2
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.219524145126343
# getting zone hvac_zone_ac_8
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.203095197677612
#
# Getting bldg avenal-public-works-yard
# getting zone hvac_zone_public_works
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.318475961685181
#
# Getting bldg north-berkeley-senior-center
# getting zone hvac_zone_ac_1
# Temp shape (14400,)
# Action shape (14400,)
# Took: 4.9544358253479
# getting zone hvac_zone_ac_3
# Temp shape (14400,)
# Action shape (14400,)
# Took: 4.992211103439331
# getting zone hvac_zone_ac_5
# Temp shape (14400,)
# Action shape (14400,)
# Took: 4.81630802154541
#
# Getting bldg berkeley-corporate-yard
# getting zone hvac_zone_parks_assembly
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.612997055053711
# getting zone hvac_zone_radioshop
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.572362899780273
# getting zone hvac_zone_s_and_u_open_office
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.525288820266724
# getting zone hvac_zone_scott_britt_rm
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.7513792514801025
# getting zone hvac_zone_cs_open_office
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.358935117721558
# getting zone hvac_zone_electricalshop
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.430370807647705
# getting zone hvac_zone_fac_main_dept
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.349712133407593
# getting zone hvac_zone_green_room
# Temp shape (14400,)
# Action shape (14400,)
# Took: 5.406804084777832

# %%
bldg = "jesse-turner-center"
zone = "hvac_zone_kitchen"
cache_name = "indoor_temperature_historic_cache"  # "action_historic_cache"
end = datetime.datetime(year=2019, month=4, day=1).replace(tzinfo=pytz.utc)
start = end - datetime.timedelta(days=10)
window = "1m"
loaded_data = pid.load_data(bldg, zone, cache_name)
err = xsg.check_data(loaded_data, start, end, window)
print(loaded_data)
# Out:
# 2018-12-02 00:00:00+00:00    71.500000
# 2018-12-02 00:05:00+00:00    71.596296
# 2018-12-02 00:10:00+00:00    71.500000
# 2018-12-02 00:15:00+00:00    71.600000
# 2018-12-02 00:20:00+00:00    71.600000
# 2018-12-02 00:25:00+00:00    71.600000
# 2018-12-02 00:30:00+00:00    71.625926
# 2018-12-02 00:35:00+00:00    71.700000
# 2018-12-02 00:40:00+00:00    71.796296
# 2018-12-02 00:45:00+00:00    71.444444
# 2018-12-02 00:50:00+00:00    71.646429
# 2018-12-02 00:55:00+00:00    71.907407
# 2018-12-02 01:00:00+00:00    71.922222
# 2018-12-02 01:05:00+00:00    71.819231
# 2018-12-02 01:10:00+00:00    71.725926
# 2018-12-02 01:15:00+00:00    71.700000
# 2018-12-02 01:20:00+00:00    71.700000
# 2018-12-02 01:25:00+00:00    71.700000
# 2018-12-02 01:30:00+00:00    71.700000
# 2018-12-02 01:35:00+00:00    71.677778
# 2018-12-02 01:40:00+00:00    71.500000
# 2018-12-02 01:45:00+00:00    71.581481
# 2018-12-02 01:50:00+00:00    71.513208
# 2018-12-02 01:55:00+00:00    71.500000
# 2018-12-02 02:00:00+00:00    71.462963
# 2018-12-02 02:05:00+00:00    71.429630
# 2018-12-02 02:10:00+00:00    71.500000
# 2018-12-02 02:15:00+00:00    71.500000
# 2018-12-02 02:20:00+00:00    71.500000
# 2018-12-02 02:25:00+00:00    71.337037
#                                ...
# 2019-03-31 21:30:00+00:00    72.535526
# 2019-03-31 21:35:00+00:00    71.918667
# 2019-03-31 21:40:00+00:00    72.124675
# 2019-03-31 21:45:00+00:00    72.257237
# 2019-03-31 21:50:00+00:00    72.364103
# 2019-03-31 21:55:00+00:00    72.400000
# 2019-03-31 22:00:00+00:00    72.400000
# 2019-03-31 22:05:00+00:00    72.400000
# 2019-03-31 22:10:00+00:00    72.400000
# 2019-03-31 22:15:00+00:00    72.400000
# 2019-03-31 22:20:00+00:00    72.475000
# 2019-03-31 22:25:00+00:00    72.500000
# 2019-03-31 22:30:00+00:00    72.500000
# 2019-03-31 22:35:00+00:00    72.374675
# 2019-03-31 22:40:00+00:00    71.789474
# 2019-03-31 22:45:00+00:00    72.200000
# 2019-03-31 22:50:00+00:00    72.500000
# 2019-03-31 22:55:00+00:00    72.219737
# 2019-03-31 23:00:00+00:00    71.853947
# 2019-03-31 23:05:00+00:00    71.900000
# 2019-03-31 23:10:00+00:00    71.666234
# 2019-03-31 23:15:00+00:00    71.269737
# 2019-03-31 23:20:00+00:00    71.266234
# 2019-03-31 23:25:00+00:00    71.542857
# 2019-03-31 23:30:00+00:00    71.891447
# 2019-03-31 23:35:00+00:00    72.100000
# 2019-03-31 23:40:00+00:00    72.122667
# 2019-03-31 23:45:00+00:00    72.200000
# 2019-03-31 23:50:00+00:00    72.200000
# 2019-03-31 23:55:00+00:00          NaN
# Freq: 300S, Length: 34560, dtype: float64

# %%
prediction_window = "5m"
seconds_prediction_window = xsg.get_window_in_sec(prediction_window)
start = datetime.datetime(year=2018, month=7, day=10).replace(tzinfo=pytz.utc)
end = start + datetime.timedelta(days=)

bldg = "berkeley-corporate-yard"
zone = "hvac_zone_parks_assembly"
raw_data_granularity = "1m"
train_ratio = 0.7
is_second_order = True
use_occupancy = False
curr_action_timesteps = 0
prev_action_timesteps = -1
method = "OLS"

at = time.time()
ctm.create_model(bldg, zone, start, end, prediction_window, raw_data_granularity, train_ratio, is_second_order,
                 use_occupancy,
                 curr_action_timesteps, prev_action_timesteps, method, True)
print(time.time() - at)
# Out:
# 0.03442811965942383

# %% [markdown]
# # Data Getters
# Ground truth for how to store and retrieve data. The file naming is building_zone. No differentiation between training and test sets.

# %%
def store_data(data, building, zone):
    data_dir = Path.cwd() / "services_data"
    if not os.path.isdir(data_dir):
        os.makedirs(data_dir)
    
    file_path = data_dir / (building + "_" + zone + ".pkl")
    if not os.path.isfile(file_path):
        return None
                                
    with open(str(file_path), "wb") as f:
        pickle.dump(data, f)

def load_data(building, zone):
    data_dir = Path.cwd() / "services_data"
    if not os.path.isdir(data_dir):
        return None

    file_path = data_dir / (building + "_" + zone + ".pkl")
    if not os.path.isfile(file_path):
        return None
                            
    with open(str(file_path), "rb") as f:
        return pickle.load(f)

# %% [markdown]
# # Get the data
# num_start and num_end are hyperparameters.

# %%
building = "avenal-animal-shelter"
zone = all_buildings_zones[building][0]
prediction_window = "5m"
seconds_prediction_window = xsg.get_window_in_sec(prediction_window)

# %%
# daterange
start = datetime.datetime(year=2018, month=7, day=1).replace(tzinfo=pytz.utc)
end = start + datetime.timedelta(days=130)

# %%
# TODO add check that the data we have stored is at least as long and has right prediction_window
# TODO Fix how we deal with nan's. some zone temperatures might get set to -1.
loaded_data = load_data(building, zone)
if loaded_data is None:
    processed_data = pid.get_preprocessed_data(building, zone, start, end, prediction_window)
    store_data(processed_data, building, zone)
else:
    processed_data = loaded_data

# %%
processed_data.shape

# %%
processed_data.head()

# %% [markdown]
# ### Add features to prepocessed_data

# %%
processed_data = pid.indoor_data_cleaning(processed_data)
processed_data = pid.add_feature_last_temperature(processed_data)
processed_data = pid.convert_categorical_action(processed_data, num_start=4, num_end=4, interval_thermal=seconds_prediction_window)

# %%
processed_data.head()

# %% [markdown]
# # Linear Regressor with all features
# This will use all available features and make it into a linear regressor.

# %% [markdown]
# ### Get training and test data

# %%
train_ratio = 0.7 # how much training data to take from given data
N = processed_data.shape[0] # number of datapoints
train_data = processed_data.iloc[:int(N*train_ratio)]
test_data = processed_data.iloc[int(N*train_ratio):]

# %%
columns_to_drop = ["action", "action_prev", "dt", "action_duration"]

# Training data
train_data = train_data[train_data["dt"] == seconds_prediction_window]
train_data = train_data.drop(columns_to_drop, axis=1)

train_y = train_data["t_next"].interpolate(method="time")
train_X = train_data.drop(["t_next"], axis=1).interpolate(method="time")

# Test data
test_data = test_data[test_data["dt"] == seconds_prediction_window]
test_data = test_data.drop(columns_to_drop, axis=1)

test_y = test_data["t_next"].interpolate(method="time")
test_X = test_data.drop(["t_next"], axis=1).interpolate(method="time")

# %%
train_X.head()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

reg = LinearRegression().fit(train_X, train_y)
reg.score(train_X, train_y)

# %% [markdown]
# # First Order Linear Regressor

# %%
train_ratio = 0.7 # how much training data to take from given data
N = processed_data.shape[0] # number of datapoints
train_data = processed_data.iloc[:int(N*train_ratio)]
test_data = processed_data.iloc[int(N*train_ratio):]

# %%
action_to_drop = []
for c in train_data.columns:
    if "action" in c and len("action") != c:
        action_to_drop.append(c)
        
columns_to_drop = action_to_drop + ["t_prev", "action_prev", "dt", "action_duration"]
  
# train data
train_data = train_data[train_data["dt"] == seconds_prediction_window]
train_data = train_data.drop(columns_to_drop, axis=1)

train_y = train_data["t_next"].interpolate(method="time")
train_X = train_data.drop(["t_next"], axis=1).interpolate(method="time")

# test data
test_data = test_data[test_data["dt"] == seconds_prediction_window]
test_data = test_data.drop(columns_to_drop, axis=1)

test_y = test_data["t_next"].interpolate(method="time")
test_X = test_data.drop(["t_next"], axis=1).interpolate(method="time")

# %%
train_X.head()

# %%
lin_reg = LinearRegression().fit(train_X, train_y)

# %% [markdown]
# # Create Tests for Regressor

# %% [markdown]
# Will try to do forecasting. If it fails, won't return anything.

# %%
def forecasting(thermal_model, data, start, duration, seconds_prediction_window, dt, is_second_order=False):

    true_data = data.loc[start:]
    
    if true_data.index[-1] < start + datetime.timedelta(seconds=duration) or true_data.index[0] != start:
        return None
    
    forecast = []

    curr_time = true_data.index[0]
    
    while curr_time <= start + datetime.timedelta(seconds=duration):
        if curr_time not in true_data.index:
            return None
        
        curr_row = true_data.loc[curr_time].to_frame().T

        if (len(forecast) < 2 and is_second_order) or (len(forecast) < 1):
            forecast.append(float(curr_row["t_in"].values))
        else:
            curr_row["t_in"] = forecast[-1]
            if is_second_order:
                curr_row["t_prev"] = forecast[-2]
            forecast.append(thermal_model.predict(curr_row)[0])

        curr_time += datetime.timedelta(seconds=float(dt.loc[curr_time]))

    
    forecast = forecast[:-1] # otherwise might predict beyond the set end
    return pd.Series(index=true_data.index[:len(forecast)], data=forecast)

# %%
dt = processed_data.loc[test_X.index[0]:test_X.index[-1]]["dt"]

N = test_X.shape[0]

forecasts = []

for i in range(N):

    start_time = test_X.index[i]
    forecast = forecasting(reg, test_X, start_time, 6*60*60, 5*60, dt, is_second_order=True)
    
    if forecast is not None:
        forecasts.append(forecast)
        
    if i % 500 == 0:
        print("Iteration:", i)
        print("Successful Forecasts:", len(forecasts))

# %% [markdown]
# # Get RMSE plot
# Will do shady stuff. At least we can have duration / interval number of predictions. so we will only use that many. Otherwise dimensions don't work

# %%
errs = []
least_points = int(6*60*60 / (5*60))

for i in range(len(forecasts)):
    forecast = forecasts[i]
    real_data = test_X.loc[forecast.index]["t_in"]
    if real_data.shape[0] >= least_points:
        errs.append((forecast - real_data).values[:least_points])
        
print("Num before", len(forecasts))
print("Num remaining", len(errs))
errs = np.vstack(errs)
errs = np.square(errs)
errs = np.mean(errs, axis=0)
errs = np.sqrt(errs)
errs.shape

# %%
errs = []

for i in range(len(forecasts)):
    forecast = forecasts[i]
    real_data = test_X.loc[forecast.index]["t_in"]
    errs.append(forecast - real_data) # assuming all forecasts have the same length. 
        
errs = np.vstack(errs)
errs = np.square(errs)
errs = np.mean(errs, axis=0)
errs = np.sqrt(errs)

# %%
plt.plot(errs)

# %%
plt.plot(errs)

# %%
# occ_plot = pd.Series(index=date_range, data=test_data["occ"][date_range])

real_plot = test_X.loc[forecast.index]["t_in"]

# real_outside_plot = new_pred_horizon.loc[date_range]["t_out"]

# real_action_plt = new_pred_horizon.loc[date_range]["action"]

# real_action_plt *= 5
# real_action_plt += 65
# real_action_plt.plot(label="action", color="darkblue")

# real_outside_plot.plot(label="t_out")

real_plot.plot(label="real", color="goldenrod")
forecast.plot(label="forecast", color="firebrick")



# first_tm_plot.plot(label="First Order TM", color="firebrick")
# plt.show()

# # second_tm_plot.plot(label="Second order TM", color="steelblue")

# lti_tm_plot.plot(label="LTI TM", color="mediumpurple")
# plt.show()


# random_forest_plot.plot(label="Random Forest",  color="black")

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()


# print("plot")
# print(occ_plot)

# occ_plot.plot()
# plt.show()

def get_rmse_plot(pred, real):
    pred = pred[:len(real)]
    real = real[:len(pred)]
    diff = pred - real
    diff = np.square(diff)
    return np.sqrt(diff.mean())

# print("lag", get_rmse_plot(tm_pred_plot, real_plot))
# print("old", get_rmse_plot(old_pred_plot, real_plot))
# print("occ lag", get_rmse_plot(lag_tm_plot, real_plot))
# print("sec order", get_rmse_plot(second_tm_pred, real_plot))
# print("sec order occ", get_rmse_plot(second_occ_tm_pred, real_plot))

# %%
def save_results(building, zone, start, end, prediction_window, raw_data_granularity, train_ratio, is_second_order, 
                 curr_action_timesteps, prev_action_timesteps, method, rmse_series, num_forecasts, forecasting_horizon):
    """Stores the results and the methods as a yamls file. The files is stores in a way that it can be used
        to configure the exact same model and get the results. 
    
    :param building: (string) building name
    :param zone: (string) zone name
    :param start: (datetime timezone aware) start of the dataset used
    :param end: (datetime timezone aware) start of the dataset used
    :param prediction_window: (int seconds) number of seconds between predictions
    :param raw_data_granularity: (int seconds) the window size of the raw data. needs to be less than prediction_window.
    :param train_ratio: (float) in (0, 1). the ratio in which to split train and test set from the given dataset. The train set comes before test set in time. 
    :param is_second_order: (bool) Whether we are using second order in temperature.
    :param curr_action_timesteps: (int) The order of the current action. Set 0 if there should only be one action.
    :param prev_action_timesteps: (int) The order of the previous action. Set 0 if it should not be used at all.
    :param method: (str) ["OLS", "random_forest", "LSTM"] are the available methods so far
    :param rmse_series: np.array the rmse of the forecasting procedure. 
    :param num_forecasts: (int) The number of forecasts which contributed to the RMSE. 
    :param forecasting_horizon: (int seconds) The horizon used when forecasting.
    :return: 
    """
    to_store = {"building": building,
               "zone": zone, 
               "start": start, 
                "end": end,
               "raw_data_granularity": raw_data_granularity,
                "prediction_window": prediction_window,
                "train_ratio": train_ratio,
                "is_second_order": is_second_order,
                "curr_action_timesteps": curr_action_timesteps,
                "prev_action_timesteps": prev_action_timesteps,
                "method": method,
                "rmse_series": rmse_series,
                "num_forecasts": num_forecasts,
                "forecasting_horizon": forecasting_horizon
               }
    
    data_dir = Path.cwd() / "model_results"
    if not os.path.isdir(data_dir):
        os.makedirs(data_dir)
    
    file_path = data_dir / (building + "_" + zone + ".pkl")
    
    if os.path.isfile(file_path):
        try:
            with open(str(file_path), "rb") as f:
                loaded_results = pickle.load(f)
            loaded_results.append(to_store)
            to_store = loaded_results
        except:
            to_store = [to_store]
    else:
        to_store = [to_store]
        
    with open(str(file_path), "wb") as f:
        pickle.dump(to_store, f)
        
def load_results(building, zone):
    data_dir = Path.cwd() / "model_results"
    if not os.path.isdir(data_dir):
        return None
    
    file_path = data_dir / (building + "_" + zone + ".pkl")
    
    if not os.path.isfile(file_path):
        return None
    
    with open(str(file_path), "rb") as f:
        return pickle.load(f)

# %%
save_results(building, zone, start, end, prediction_window, 60, train_ratio, True, 
                 4, 4, "OLS", errs, 6167, 6*60*60)

# %%
load_results(building, zone)

# %% [markdown]
# # Create Model and run on all Buildings/Zones

# %%
import create_test_models as ctm
import datetime
import pytz
import xbos_services_getter as xsg

building_zone_names_stub = xsg.get_building_zone_names_stub()
all_building_zones = xsg.get_all_buildings_zones(building_zone_names_stub)

start = datetime.datetime(year=2018, month=7, day=1).replace(tzinfo=pytz.utc)
end = start + datetime.timedelta(days=10)


for bldg in list(not_working.keys())[1:]:
    print("Building", bldg)
    for zone in all_building_zones[bldg]:
        print("Zone", zone)
        reg, p_data, test_X, test_y = ctm.create_model(bldg, zone, 
                             start, end, "5m", "1m", 0.7, True, 
                             1, 1, "OLS")
#         try:
#             reg, p_data, test_X, test_y = ctm.create_model(bldg, zone, 
#                              start, end, "5m", "1m", 0.7, True, 
#                              1, 1, "OLS")
#             print("Score", reg.score(test_X, test_y))

#         except:
#             if bldg not in not_working:
#                 not_working[bldg] = []
#             not_working[bldg].append(zone)
    
    print("")
# Out:
# Building hayward-station-8
# Zone HVAC_Zone_F-2
# ---------------------------------------------------------------------------
# _Rendezvous                               Traceback (most recent call last)
# <ipython-input-4-a83928f35461> in <module>
#      17         reg, p_data, test_X, test_y = ctm.create_model(bldg, zone,
#      18                              start, end, "5m", "1m", 0.7, True,
# ---> 19                              1, 1, "OLS")
#      20 #         try:
#      21 #             reg, p_data, test_X, test_y = ctm.create_model(bldg, zone,
#
# ~/BETS/XBOS/services/indoor_temperature_prediction/create_test_models.py in create_model(building, zone, start, end, prediction_window, raw_data_granularity, train_ratio, is_second_order, curr_action_timesteps, prev_action_timesteps, method)
#      74     loaded_data = load_data(building, zone)
#      75     if loaded_data is None:
# ---> 76         processed_data = pid.get_preprocessed_data(building, zone, start, end, prediction_window, raw_data_granularity)
#      77         store_data(processed_data, building, zone)
#      78     else:
#
# ~/BETS/XBOS/services/indoor_temperature_prediction/process_indoor_data.py in get_preprocessed_data(building, zone, start, end, window, raw_data_granularity)
#      34     indoor_historic_stub = xsg.get_indoor_historic_stub()
#      35     indoor_temperatures = xsg.get_indoor_temperature_historic(indoor_historic_stub, building, zone, start, end,
# ---> 36                                                              raw_data_granularity)
#      37     indoor_actions = xsg.get_actions_historic(indoor_historic_stub, building, zone, start, end, raw_data_granularity)
#      38
#
# ~/BETS/xbos_services_getter/xbos_services_getter/xbos_services_getter.py in get_indoor_temperature_historic(indoor_historic_stub, building, zone, start, end, window)
#     299     historic_indoor_response = indoor_historic_stub.GetRawTemperatures(
#     300         indoor_temperature_action_pb2.Request(building=building, zone=zone, start=start_unix, end=end_unix,
# --> 301                                               window=window))
#     302
#     303     # process data
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials)
#     531     def __call__(self, request, timeout=None, metadata=None, credentials=None):
#     532         state, call, = self._blocking(request, timeout, metadata, credentials)
# --> 533         return _end_unary_response_blocking(state, call, False, None)
#     534
#     535     def with_call(self, request, timeout=None, metadata=None, credentials=None):
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     465             return state.response
#     466     else:
# --> 467         raise _Rendezvous(state, None, None, deadline)
#     468
#     469
#
# _Rendezvous: <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "No data received from database."
# 	debug_error_string = "{"created":"@1553988333.716740000","description":"Error received from peer","file":"src/core/lib/surface/call.cc","file_line":1017,"grpc_message":"No data received from database.","grpc_status":3}"
# >

# %%
not_working = {'hayward-station-1': ['HVAC_Zone_AC-7',
  'HVAC_Zone_AC-6',
  'HVAC_Zone_AC-5',
  'HVAC_Zone_AC-4',
  'HVAC_Zone_AC-3',
  'HVAC_Zone_AC-2',
  'HVAC_Zone_AC-1'],
 'hayward-station-8': ['HVAC_Zone_F-2', 'HVAC_Zone_F-3', 'HVAC_Zone_F-1'],
 'north-berkeley-senior-center': ['HVAC_Zone_AC-5',
  'HVAC_Zone_AC-3',
  'HVAC_Zone_AC-1'],
 'csu-dominguez-hills': ['HVAC_Zone_SAC_2134',
  'HVAC_Zone_SAC_2113A',
  'HVAC_Zone_SAC_2149',
  'HVAC_Zone_SAC_2103',
  'HVAC_Zone_SAC_2107',
  'HVAC_Zone_SAC_2144',
  'HVAC_Zone_Sac_2_Corridor',
  'HVAC_Zone_SAC_2114',
  'HVAC_Zone_SAC_2113',
  'HVAC_Zone_SAC-2106',
  'HVAC_Zone_SAC-2104',
  'HVAC_Zone_SAC-2102',
  'HVAC_Zone_SAC_2150',
  'HVAC_Zone_SAC_2105',
  'HVAC_Zone_SAC_2101',
  'HVAC_Zone_SAC_2129',
  'HVAC_Zone_SAC_2126'],
 'orinda-community-center': ['HVAC_Zone_RM2',
  'HVAC_Zone_RM1',
  'HVAC_Zone_RM6',
  'HVAC_Zone_RM7',
  'HVAC_Zone_AC-8',
  'HVAC_Zone_AC-7',
  'HVAC_Zone_AC-6',
  'HVAC_Zone_AC-5',
  'HVAC_Zone_AC-4',
  'HVAC_Zone_AC-3',
  'HVAC_Zone_AC-2',
  'HVAC_Zone_AC-1',
  'HVAC_Zone_Kinder_GYM',
  'HVAC_Zone_FRONT_OFFICE'],
 'avenal-veterans-hall': ['HVAC_Zone_AC-6',
  'HVAC_Zone_AC-5',
  'HVAC_Zone_AC-4',
  'HVAC_Zone_AC-3',
  'HVAC_Zone_AC-2',
  'HVAC_Zone_AC-1'],
 'south-berkeley-senior-center': ['HVAC_Zone_AC-3',
  'HVAC_Zone_Front_Office',
  'HVAC_Zone_AC-2']}

# %% [markdown]
# # Explore Data for South Berkeley Senior Center

# %%
building_zone_names_stub = xsg.get_building_zone_names_stub()
all_buildings_zones = xsg.get_all_buildings_zones(building_zone_names_stub)

# %%
building = "south-berkeley-senior-center"
zones = all_buildings_zones[building]

# %%
# get data for all zones
end = datetime.datetime.utcnow().replace(tzinfo=pytz.utc).astimezone(pytz.timezone('US/Pacific'))
start = end - datetime.timedelta(days=365)
prediction_window = "5m"
raw_data_granularity = "1m"
is_second_order = True
train_ratio = 1
use_occupancy = True
curr_action_timesteps = 0
prev_action_timesteps = -1
check_data = True

# %%
zones_data = {}
print(end)
print(start)
for iter_zone in zones:
    print("zone", iter_zone)
    a = time.time()
    zones_data[iter_zone] = ctm.get_train_test(building, iter_zone, start, end, prediction_window, raw_data_granularity, train_ratio, is_second_order,
                 use_occupancy,
                 curr_action_timesteps, prev_action_timesteps, check_data=False)
    print("TIME", time.time() - a)
# Out:
# 2019-05-29 17:11:21.221457-07:00
# 2018-05-29 17:11:21.221457-07:00
# zone hvac_zone_ac_2
#                            action  action_duration  action_prev   dt  \
# time
# 2018-05-30 10:06:21-07:00     1.0              300          0.0  300
# 2018-05-30 10:11:21-07:00     1.0              540          0.0  240
# 2018-05-30 10:15:21-07:00     0.0              300          1.0  300
# 2018-05-30 10:20:21-07:00     0.0              600          1.0  300
# 2018-05-30 10:25:21-07:00     0.0              900          1.0  300
# 2018-05-30 10:30:21-07:00     0.0             1200          1.0  300
# 2018-05-30 10:35:21-07:00     0.0             1500          1.0  300
# 2018-05-30 10:40:21-07:00     0.0             1620          1.0  120
# 2019-05-29 16:06:21-07:00  72.800000  72.800000
# 2019-05-29 16:11:21-07:00  72.800000  72.700000
# 2019-05-29 16:16:21-07:00  72.700000  72.700000
# 2019-05-29 16:21:21-07:00  72.700000  72.733333
# 2019-05-29 16:26:21-07:00  72.733333  72.800000
# 2019-05-29 16:31:21-07:00  72.800000  73.000000
# 2019-05-29 16:36:21-07:00  73.000000  73.100000
# 2019-05-29 16:41:21-07:00  73.100000  73.100000
# 2019-05-29 16:46:21-07:00  73.100000  73.200000
# 2019-05-29 16:51:21-07:00  73.200000  73.100000
# 2019-05-29 16:56:21-07:00  73.100000  73.200000
# 2019-05-29 17:01:21-07:00  73.200000  73.233333
# 2019-05-29 17:06:21-07:00  73.233333  73.300000
#
#                                                                        t_out  \
# time
# 2018-05-30 10:06:21-07:00            temperature    54.432514
# dtype: float64
# 2018-05-30 10:11:21-07:00            temperature    55.437519
# dtype: float64
# 2018-05-30 10:15:21-07:00            temperature    55.940022
# dtype: float64
# 2018-05-30 10:20:21-07:00            temperature    55.233217
# dtype: float64
# 2018-05-30 10:25:21-07:00            temperature    54.526411
# dtype: float64
# 2018-05-30 10:30:21-07:00            temperature    53.819606
# dtype: float64
# 2018-05-30 10:35:21-07:00            temperature    53.921312
# dtype: float64
# 2018-05-30 10:40:21-07:00            temperature    54.023018
# dtype: float64
# 2018-05-30 10:42:21-07:00            temperature    54.124724
# dtype: float64
# 2018-05-30 10:47:21-07:00            temperature    54.438219
# dtype: float64
# 2018-05-30 10:49:21-07:00            temperature    54.438219
# dtype: float64
# 2018-05-30 10:54:21-07:00            temperature    54.751715
# dtype: float64
# 2018-05-30 10:59:21-07:00            temperature    55.065211
# dtype: float64
# 2018-05-30 11:04:21-07:00            temperature    55.730004
# dtype: float64
# 2018-05-30 11:09:21-07:00            temperature    56.394796
# dtype: float64
# 2018-05-30 11:14:21-07:00            temperature    57.059589
# dtype: float64
# 2018-05-30 11:19:21-07:00            temperature    57.003193
# dtype: float64
# 2018-05-30 11:24:21-07:00            temperature    56.946796
# dtype: float64
# 2018-05-30 11:29:21-07:00              temperature    56.8904
# dtype: float64
# 2018-05-30 11:34:21-07:00            temperature    56.983701
# dtype: float64
# 2018-05-30 11:35:21-07:00            temperature    56.983701
# dtype: float64
# 2018-05-30 11:40:21-07:00            temperature    57.077003
# dtype: float64
# 2018-05-30 11:41:21-07:00            temperature    57.123653
# dtype: float64
# 2018-05-30 11:46:21-07:00            temperature    57.170304
# dtype: float64
# 2018-05-30 11:51:21-07:00            temperature    57.170304
# dtype: float64
# 2018-05-30 11:56:21-07:00            temperature    57.170304
# dtype: float64
# 2018-05-30 12:01:21-07:00            temperature    57.101153
# dtype: float64
# 2018-05-30 12:06:21-07:00            temperature    56.962852
# dtype: float64
# 2018-05-30 12:11:21-07:00            temperature    56.824551
# dtype: float64
# 2018-05-30 12:16:21-07:00            temperature    56.637048
# dtype: float64
# ...                                                                      ...
# 2019-05-29 14:41:21-07:00             temperature    68.22425
# dtype: float64
# 2019-05-29 14:46:21-07:00              temperature    68.4851
# dtype: float64
# 2019-05-29 14:51:21-07:00            temperature    68.387675
# dtype: float64
# 2019-05-29 14:56:21-07:00            temperature    68.192825
# dtype: float64
# 2019-05-29 15:01:21-07:00              temperature    68.0795
# dtype: float64
# 2019-05-29 15:06:21-07:00              temperature    68.0477
# dtype: float64
# 2019-05-29 15:11:21-07:00              temperature    68.0159
# dtype: float64
# 2019-05-29 15:16:21-07:00                 temperature    68.0
# dtype: float64
# 2019-05-29 15:21:21-07:00             temperature    68.45135
# dtype: float64
# 2019-05-29 15:26:21-07:00             temperature    69.35405
# dtype: float64
# 2019-05-29 15:31:21-07:00              temperature    69.9104
# dtype: float64
# 2019-05-29 15:36:21-07:00              temperature    70.1204
# dtype: float64
# 2019-05-29 15:41:21-07:00              temperature    70.3304
# dtype: float64
# 2019-05-29 15:46:21-07:00              temperature    70.4354
# dtype: float64
# 2019-05-29 15:51:21-07:00            temperature    70.499075
# dtype: float64
# 2019-05-29 15:56:21-07:00            temperature    70.626425
# dtype: float64
# 2019-05-29 16:01:21-07:00             temperature    70.24175
# dtype: float64
# 2019-05-29 16:06:21-07:00             temperature    69.34505
# dtype: float64
# 2019-05-29 16:11:21-07:00             temperature    68.44835
# dtype: float64
# 2019-05-29 16:16:21-07:00                temperature    67.46
# dtype: float64
# 2019-05-29 16:21:21-07:00                temperature    66.92
# dtype: float64
# 2019-05-29 16:26:21-07:00                temperature    66.92
# dtype: float64
# 2019-05-29 16:31:21-07:00             temperature    67.42835
# dtype: float64
# 2019-05-29 16:36:21-07:00             temperature    68.44505
# dtype: float64
# 2019-05-29 16:41:21-07:00             temperature    69.46175
# dtype: float64
# 2019-05-29 16:46:21-07:00              temperature    69.9701
# dtype: float64
# 2019-05-29 16:51:21-07:00              temperature    70.0538
# dtype: float64
# 2019-05-29 16:56:21-07:00              temperature    70.2212
# dtype: float64
# 2019-05-29 17:01:21-07:00              temperature    70.3049
# dtype: float64
# 2019-05-29 17:06:21-07:00  temperature   NaN
# unit          NaN
# dtype: flo...
#
#                                                        occ  \
# time
# 2018-05-30 10:06:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:11:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:15:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:20:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:25:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:30:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:35:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:40:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:42:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:47:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:49:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:54:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 10:59:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:04:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:09:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:14:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:19:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:24:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:29:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:34:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:35:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:40:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:41:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:46:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:51:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 11:56:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 12:01:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 12:06:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 12:11:21-07:00  occupancy    1.0
# dtype: float64
# 2018-05-30 12:16:21-07:00  occupancy    1.0
# dtype: float64
# ...                                                    ...
# 2019-05-29 14:41:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 14:46:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 14:51:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 14:56:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:01:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:06:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:11:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:16:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:21:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:26:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:31:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:36:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:41:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:46:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:51:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 15:56:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:01:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:06:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:11:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:16:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:21:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:26:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:31:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:36:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:41:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:46:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:51:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29 16:56:21-07:00  occupancy    1.0
# dtype: float64
# 2019-05-29

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-d51357f3ede1> in <module>
#       7     zones_data[iter_zone] = ctm.get_train_test(building, iter_zone, start, end, prediction_window, raw_data_granularity, train_ratio, is_second_order,
#       8                  use_occupancy,
# ----> 9                  curr_action_timesteps, prev_action_timesteps, check_data=False)
#      10     print("TIME", time.time() - a)
#      11
#
# ~/BETS/XBOS/services/indoor_temperature_prediction/create_models.py in get_train_test(building, zone, start, end, prediction_window, raw_data_granularity, train_ratio, is_second_order, use_occupancy, curr_action_timesteps, prev_action_timesteps, check_data)
#      75     # TODO add check that the data we have stored is at least as long and has right prediction_window
#      76     # TODO Fix how we deal with nan's. some zone temperatures might get set to -1.
# ---> 77     loaded_data = load_data(building, zone)
#      78     print(loaded_data)
#      79     err = xsg.check_data(loaded_data, start, end, prediction_window, check_nan=True)
#
# ~/BETS/XBOS/services/indoor_temperature_prediction/create_models.py in load_data(building, zone)
#      39
#      40     with open(str(file_path), "rb") as f:
# ---> 41         return pickle.load(f)
#      42
#      43
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/pandas/core/internals/managers.py in __setstate__(self, state)
#     257             self.axes = [ensure_index(ax) for ax in state['axes']]
#     258             self.blocks = tuple(unpickle_block(b['values'], b['mgr_locs'])
# --> 259                                 for b in state['blocks'])
#     260         else:
#     261             # discard anything after 3rd, support beta pickling format for a
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/pandas/core/internals/managers.py in <genexpr>(.0)
#     257             self.axes = [ensure_index(ax) for ax in state['axes']]
#     258             self.blocks = tuple(unpickle_block(b['values'], b['mgr_locs'])
# --> 259                                 for b in state['blocks'])
#     260         else:
#     261             # discard anything after 3rd, support beta pickling format for a
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/pandas/core/internals/managers.py in unpickle_block(values, mgr_locs)
#     250     def __setstate__(self, state):
#     251         def unpickle_block(values, mgr_locs):
# --> 252             return make_block(values, placement=mgr_locs)
#     253
#     254         if (isinstance(state, tuple) and len(state) >= 4 and
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3086     if klass is None:
#    3087         dtype = dtype or values.dtype
# -> 3088         klass = get_block_type(values, dtype)
#    3089
#    3090     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values):
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    3051         # Need this first(ish) so that Sparse[datetime] is sparse
#    3052         cls = ExtensionBlock
# -> 3053     elif is_categorical(values):
#    3054         cls = CategoricalBlock
#    3055     elif issubclass(vtype, np.datetime64):
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_categorical(arr)
#     289     """
#     290
# --> 291     return isinstance(arr, ABCCategorical) or is_categorical_dtype(arr)
#     292
#     293
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     600     if arr_or_dtype is None:
#     601         return False
# --> 602     return CategoricalDtype.is_dtype(arr_or_dtype)
#     603
#     604
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#      99
#     100         if isinstance(dtype, (ABCSeries, ABCIndexClass,
# --> 101                               ABCDataFrame, np.dtype)):
#     102             # https://github.com/pandas-dev/pandas/issues/22960
#     103             # avoid passing data to `construct_from_string`. This could
#
# ~/miniconda3/envs/venv-dr3/lib/python3.6/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#       7     @classmethod
#       8     def _check(cls, inst):
# ----> 9         return getattr(inst, attr, '_typ') in comp
#      10
#      11     dct = dict(__instancecheck__=_check, __subclasscheck__=_check)
#
# KeyboardInterrupt:

# %%
def foo():
    xsg.get_occupancy_stub()

# %%
_INTERVAL = "5m"  # minutes # TODO allow for getting multiples of 5. Prediction horizon.

building = 'avenal-movie-theatre'
zone = 'hvac_zone_lobby'

end = datetime.datetime(year=2019, month=4, day=1).replace(
    tzinfo=pytz.utc)  # datetime.datetime.utcnow().replace(tzinfo=pytz.utc) # TODO make environ var.
start = end - datetime.timedelta(days=365)

ctm.get_train_test(building=building,
                                                     zone=zone,
                                                     start=start,
                                                     end=end,
                                                     prediction_window=_INTERVAL,
                                                     raw_data_granularity="1m",
                                                     train_ratio=1,
                                                     is_second_order=True,
                                                     use_occupancy=False,
                                                     curr_action_timesteps=0,
                                                     prev_action_timesteps=-1,
                                                     check_data=False)
# Out:
#                            action  action_duration  action_prev   dt  \
# time
# 2018-04-06 20:04:00+00:00     2.0              300          0.0  300
# 2018-04-06 20:09:00+00:00     2.0              600          0.0  300
# 2018-04-06 20:14:00+00:00     2.0              900          0.0  300
# 2018-04-06 20:19:00+00:00     2.0             1200          0.0  300
# 2018-04-06 20:24:00+00:00     2.0             1500          0.0  300
# 2018-04-06 20:29:00+00:00     2.0             1800          0.0  300
# 2018-04-06 20:34:00+00:00     2.0             2100          0.0  300
# 2018-04-06 20:39:00+00:00     2.0             2400          0.0  300
# 2018-04-06 20:44:00+00:00     2.0             2700          0.0  300
# 2018-04-06 20:49:00+00:00     2.0             3000          0.0  300
# 2018-04-06 20:54:00+00:00     2.0             3300          0.0  300
# 2018-04-06 20:59:00+00:00     2.0             3600          0.0  300
# 2018-04-06 21:04:00+00:00     2.0             3900          0.0  300
# 2018-04-06 21:09:00+00:00     2.0             4200          0.0  300
# 2018-04-06 21:14:00+00:00     2.0             4500          0.0  300
# 2018-04-06 21:19:00+00:00     2.0             4800          0.0  300
# 2018-04-06 21:24:00+00:00     2.0             5100          0.0  300
# 2018-04-06 21:29:00+00:00     2.0             5400          0.0  300
# 2018-04-06 21:34:00+00:00     2.0             5700          0.0  300
# 2018-04-06 21:39:00+00:00     2.0             6000          0.0  300
# 2018-04-06 21:44:00+00:00     2.0             6300          0.0  300
# 2018-04-06 21:49:00+00:00     2.0             6600          0.0  300
# 2018-04-06 21:54:00+00:00     2.0             6900          0.0  300
# 2018-04-06 21:59:00+00:00     2.0             7200          0.0  300
# 2018-04-06 22:04:00+00:00     2.0             7500          0.0  300
# 2018-04-06 22:09:00+00:00     2.0             7800          0.0  300
# 2018-04-06 22:14:00+00:00     2.0             8100          0.0  300
# 2018-04-06 22:19:00+00:00     2.0             8400          0.0  300
# 2018-04-06 22:24:00+00:00     2.0             8700          0.0  300
# 2018-04-06 22:29:00+00:00     2.0             9000          0.0  300
# ...                           ...              ...          ...  ...
# 2019-03-31 21:23:00+00:00     0.0           170100          1.0  300
# 2019-03-31 21:28:00+00:00     0.0           170400          1.0  300
# 2019-03-31 21:33:00+00:00     0.0           170700          1.0  300
# 2019-03-31 21:38:00+00:00     0.0           171000          1.0  300
# 2019-03-31 21:43:00+00:00     0.0           171300          1.0  300
# 2019-03-31 21:48:00+00:00     0.0           171600          1.0  300
# 2019-03-31 21:53:00+00:00     0.0           171900          1.0  300
# 2019-03-31 21:58:00+00:00     0.0           172200          1.0  300
# 2019-03-31 22:03:00+00:00     0.0           172500          1.0  300
# 2019-03-31 22:08:00+00:00     0.0           172800          1.0  300
# 2018-04-06 22:29:00+00:00  73.600000  73.700000
# ...                              ...        ...
# 2019-03-31 21:23:00+00:00  67.100000  67.100000
# 2019-03-31 21:28:00+00:00  67.100000  67.200000
# 2019-03-31 21:33:00+00:00  67.200000  67.100000
# 2019-03-31 21:38:00+00:00  67.100000  67.100000
# 2019-03-31 21:43:00+00:00  67.100000  67.100000
# 2019-03-31 21:48:00+00:00  67.100000  67.118182
# 2019-03-31 21:53:00+00:00  67.118182  67.200000
# 2019-03-31 21:58:00+00:00  67.200000  67.300000
# 2019-03-31 22:03:00+00:00  67.300000  67.300000
# 2019-03-31 22:08:00+00:00  67.300000  67.300000
# 2019-03-31 22:13:00+00:00  67.300000  67.300000
# 2019-03-31 22:18:00+00:00  67.300000  67.300000
# 2019-03-31 22:23:00+00:00  67.300000  67.200000
# 2019-03-31 22:28:00+00:00  67.200000  67.300000
# 2019-03-31 22:33:00+00:00  67.300000  67.400000
# 2019-03-31 22:38:00+00:00  67.400000  67.400000
# 2019-03-31 22:43:00+00:00  67.400000  67.600000
# 2019-03-31 22:48:00+00:00  67.600000  67.300000
# 2019-03-31 22:53:00+00:00  67.300000  67.200000
# 2019-03-31 22:58:00+00:00  67.200000  67.300000
# 2019-03-31 23:03:00+00:00  67.300000  67.200000
# 2019-03-31 23:08:00+00:00  67.200000  67.300000
# 2019-03-31 23:13:00+00:00  67.300000  67.400000
# 2019-03-31 23:18:00+00:00  67.400000  67.300000
# 2019-03-31 23:23:00+00:00  67.300000  67.300000
# 2019-03-31 23:28:00+00:00  67.300000  67.300000
# 2019-03-31 23:33:00+00:00  67.300000  67.300000
# 2019-03-31 23:38:00+00:00  67.300000  67.336364
# 2019-03-31 23:43:00+00:00  67.336364  67.400000
# 2019-03-31 23:48:00+00:00  67.400000  67.400000
#
#                                                              t_out  \
# time
# 2018-04-06 20:04:00+00:00  temperature    67.750905
# dtype: float64
# 2018-04-06 20:09:00+00:00    temperature    68.5021
# dtype: float64
# 2018-04-06 20:14:00+00:00  temperature    68.250852
# dtype: float64
# 2018-04-06 20:19:00+00:00  temperature    67.999604
# dtype: float64
# 2018-04-06 20:24:00+00:00  temperature    68.500853
# dtype: float64
# 2018-04-06 20:29:00+00:00  temperature    69.002101
# dtype: float64
# 2018-04-06 20:34:00+00:00  temperature    69.000854
# dtype: float64
# 2018-04-06 20:39:00+00:00  temperature    68.999608
# dtype: float64
# 2018-04-06 20:44:00+00:00      temperature    71.01
# dtype: float64
# 2018-04-06 20:49:00+00:00  temperature    69.752304
# dtype: float64
# 2018-04-06 20:54:00+00:00  temperature    69.375956
# dtype: float64
# 2018-04-06 20:59:00+00:00  temperature    68.999608
# dtype: float64
# 2018-04-06 21:04:00+00:00  temperature    69.624751
# dtype: float64
# 2018-04-06 21:09:00+00:00  temperature    70.249894
# dtype: float64
# 2018-04-06 21:14:00+00:00  temperature    70.249894
# dtype: float64
# 2018-04-06 21:19:00+00:00  temperature    70.249894
# dtype: float64
# 2018-04-06 21:24:00+00:00       temperature    70.0
# dtype: float64
# 2018-04-06 21:29:00+00:00  temperature    69.999886
# dtype: float64
# 2018-04-06 21:34:00+00:00  temperature    69.999886
# dtype: float64
# 2018-04-06 21:39:00+00:00  temperature    69.999886
# dtype: float64
# 2018-04-06 21:44:00+00:00       temperature    70.0
# dtype: float64
# 2018-04-06 21:49:00+00:00  temperature    69.999941
# dtype: float64
# 2018-04-06 21:54:00+00:00  temperature    70.126164
# dtype: float64
# 2018-04-06 21:59:00+00:00  temperature    70.252386
# dtype: float64
# 2018-04-06 22:04:00+00:00  temperature    70.376143
# dtype: float64
# 2018-04-06 22:09:00+00:00  temperature    70.499901
# dtype: float64
# 2018-04-06 22:14:00+00:00  temperature    70.501147
# dtype: float64
# 2018-04-06 22:19:00+00:00  temperature    70.502394
# dtype: float64
# 2018-04-06 22:24:00+00:00  temperature    70.501147
# dtype: float64
# 2018-04-06 22:29:00+00:00  temperature    70.499901
# dtype: float64
# ...                                                            ...
# 2019-03-31 21:23:00+00:00   temperature    72.33332
# dtype: float64
# 2019-03-31 21:28:00+00:00  temperature    72.666644
# dtype: float64
# 2019-03-31 21:33:00+00:00  temperature    72.999968
# dtype: float64
# 2019-03-31 21:38:00+00:00  temperature    72.999968
# dtype: float64
# 2019-03-31 21:43:00+00:00  temperature    72.999968
# dtype: float64
# 2019-03-31 21:48:00+00:00  temperature    72.999968
# dtype: float64
# 2019-03-31 21:53:00+00:00  temperature    72.999968
# dtype: float64
# 2019-03-31 21:58:00+00:00  temperature    72.999968
# dtype: float64
# 2019-03-31 22:03:00+00:00  temperature    72.999968
# dtype: float64
# 2019-03-31 22:08:00+00:00  temperature    72.999968
# dtype: float64
# 2019-03-31 22:13:00+00:00   temperature    73.49999
# dtype: float64
# 2019-03-31 22:18:00+00:00  temperature    74.000012
# dtype: float64
# 2019-03-31 22:23:00+00:00  temperature    74.000012
# dtype: float64
# 2019-03-31 22:28:00+00:00  temperature    74.000012
# dtype: float64
# 2019-03-31 22:33:00+00:00  temperature    74.000012
# dtype: float64
# 2019-03-31 22:38:00+00:00  temperature    74.000012
# dtype: float64
# 2019-03-31 22:43:00+00:00  temperature    74.499998
# dtype: float64
# 2019-03-31 22:48:00+00:00  temperature    74.999984
# dtype: float64
# 2019-03-31 22:53:00+00:00   temperature    74.66666
# dtype: float64
# 2019-03-31 22:58:00+00:00  temperature    74.333336
# dtype: float64
# 2019-03-31 23:03:00+00:00  temperature    74.000012
# dtype: float64
# 2019-03-31 23:08:00+00:00  temperature    74.000012
# dtype: float64
# 2019-03-31 23:13:00+00:00  temperature    74.499998
# dtype: float64
# 2019-03-31 23:18:00+00:00  temperature    74.999984
# dtype: float64
# 2019-03-31 23:23:00+00:00  temperature    74.999984
# dtype: float64
# 2019-03-31 23:28:00+00:00  temperature    74.999984
# dtype: float64
# 2019-03-31 23:33:00+00:00  temperature    74.999984
# dtype: float64
# 2019-03-31 23:38:00+00:00  temperature    74.999984
# dtype: float64
# 2019-03-31 23:43:00+00:00  temperature    74.999984
# dtype: float64
# 2019-03-31 23:48:00+00:00  temperature    74.999984
# dtype: float64
#
#                                                        occ  \
# time
# 2018-04-06 20:04:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 20:09:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 20:14:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 20:19:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 20:24:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 20:29:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 20:34:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 20:39:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 20:44:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 20:49:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 20:54:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 20:59:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:04:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:09:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:14:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:19:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:24:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:29:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:34:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:39:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:44:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:49:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:54:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 21:59:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 22:04:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 22:09:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 22:14:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 22:19:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 22:24:00+00:00  occupancy    1.0
# dtype: float64
# 2018-04-06 22:29:00+00:00  occupancy    1.0
# dtype: float64
# ...                                                    ...
# 2019-03-31 21:23:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 21:28:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 21:33:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 21:38:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 21:43:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 21:48:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 21:53:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 21:58:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:03:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:08:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:13:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:18:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:23:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:28:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:33:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:38:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:43:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:48:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:53:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 22:58:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 23:03:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 23:08:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 23:13:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 23:18:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 23:23:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 23:28:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 23:33:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 23:38:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 23:43:00+00:00  occupancy    0.0
# dtype: float64
# 2019-03-31 23:48:00+00:00  occupancy    0.0
# dtype: float64
#
#                            temperature_zone_hvac_zone_main_hallway  \
# time
# 2018-04-06 20:04:00+00:00                                69.100000
# 2018-04-06 20:09:00+00:00                                69.148148
# 2018-04-06 20:14:00+00:00                                68.992727
# 2018-04-06 20:19:00+00:00                                68.966667
